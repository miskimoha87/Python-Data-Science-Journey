# %% [markdown]
# ##import libararys

# %%
#mport libarary pandas
#syntax for import (import library_items as pd)
import pandas as pd

# %% [markdown]
# # load dataset

# %%
#read Data from Google Drive
data = pd.read_excel("/content/excel-hotel_analaysis.xlsx")

# %% [markdown]
# #Reading first 5 rows

# %%
data.head()

# %% [markdown]
# #Read last 5 rows

# %%
data.tail()

# %%
data.sample(5)
# Out:
#     Booking_ID Booking_Date Room_Type Customer_Type Nights Room_Rate  \
# 279   BKG00079   2025-04-10  Standard           New      6     48.61
# 269   BKG00012   2026-04-08    Family           New      7     94.56
# 6     BKG00065   2025-04-26    Deluxe           New      2     72.98
# 79    BKG00262   2025-04-21     Suite           NaN      2       145
# 42    BKG00059   2025-07-29     Suite     Corporate      9    130.59
#
#     Booking_Status
# 279      Completed
# 269      Cancelled
# 6        Cancelled
# 79               -
# 42       Completed

# %%
data.shape
# Out:
# (302, 7)

# %% [markdown]
# ## Display all colomn names of this dataset using property

# %%
data.columns
# Out:
# Index(['Booking_ID', 'Booking_Date', 'Room_Type', 'Customer_Type', 'Nights',
#        'Room_Rate', 'Booking_Status'],
#       dtype='object')

# %% [markdown]
# Display the data tyoes of my dataset using property (datatype)

# %%
data.dtypes
# Out:
# Booking_ID                object
# Booking_Date      datetime64[ns]
# Room_Type                 object
# Customer_Type             object
# Nights                    object
# Room_Rate                 object
# Booking_Status            object
# dtype: object

# %% [markdown]
# ##Genaral summary of data frame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 302 entries, 0 to 301
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Booking_ID      286 non-null    object
#  1   Booking_Date    283 non-null    datetime64[ns]
#  2   Room_Type       283 non-null    object
#  3   Customer_Type   284 non-null    object
#  4   Nights          284 non-null    object
#  5   Room_Rate       284 non-null    object
#  6   Booking_Status  283 non-null    object
# dtypes: datetime64[ns](1), object(6)
# memory usage: 16.6+ KB

# %%
data.describe(include="all")
# Out:
#        Booking_ID                   Booking_Date Room_Type Customer_Type  \
# count         286                            283       283           284
# unique        278                            NaN         7             5
# top      BKG00160                            NaN  Standard           New
# freq            2                            NaN       127           123
# mean          NaN  2025-10-15 07:17:35.830388736       NaN           NaN
# min           NaN            2025-01-02 00:00:00       NaN           NaN
# 25%           NaN            2025-05-08 12:00:00       NaN           NaN
# 50%           NaN            2025-10-15 00:00:00       NaN           NaN
# 75%           NaN            2026-03-04 12:00:00       NaN           NaN
# max           NaN            2026-07-31 00:00:00       NaN           NaN
#
#         Nights  Room_Rate Booking_Status
# count    284.0     284.00            283
# unique    13.0     274.00              8
# ...
